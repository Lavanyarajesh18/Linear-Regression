# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("simplelinearregression.csv")

# %%
df.head()
# Out:
#    Age  Premium
# 0   18    10000
# 1   22    15000
# 2   23    18000
# 3   26    21000
# 4   28    24000

# %%
df.shape
# Out:
# (7, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Age      7 non-null      int64
#  1   Premium  7 non-null      int64
# dtypes: int64(2)
# memory usage: 244.0 bytes

# %%
df.describe()
# Out:
#              Age       Premium
# count   7.000000      7.000000
# mean   25.857143  20214.285714
# std     5.273474   6283.955382
# min    18.000000  10000.000000
# 25%    22.500000  16500.000000
# 50%    26.000000  21000.000000
# 75%    29.500000  25250.000000
# max    33.000000  27000.000000

# %%
x=df.iloc[:,0:1]
x
# Out:
#    Age
# 0   18
# 1   22
# 2   23
# 3   26
# 4   28
# 5   31
# 6   33

# %%
y=df.iloc[:,1:]
y
# Out:
#    Premium
# 0    10000
# 1    15000
# 2    18000
# 3    21000
# 4    24000
# 5    26500
# 6    27000

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=101)
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_train_pred1=lr.predict(x_train)
y_test_pred1=lr.predict(x_test)

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test_pred1,y_test))
print(r2_score(y_train_pred1,y_train))
# Out:
# 0.9600390842085195
# 0.9391377852916315

# %%
plt.scatter(df["Age"],df["Premium"])
plt.plot(x_train,lr.predict(x_train),color="red")
plt.show()

# %%
sns.distplot(y_test-y_test_pred1)
plt.show()

# %%
plt.scatter(y_test, y_test_pred1)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc_xtrain=sc.fit_transform(x_train)
sc_xtest=sc.fit_transform(x_test)

# %%
lr.fit(sc_xtrain,y_train)
# Out:
# LinearRegression()

# %%
y_train_pred=lr.predict(sc_xtrain)
y_test_pred=lr.predict(sc_xtest)

# %%
print(r2_score(y_test_pred,y_test))
print(r2_score(y_train_pred,y_train))
# Out:
# -3.119184061604689
# 0.9475555555555556

# %%
sns.distplot(y_test-y_test_pred1)
plt.show()

# %%
plt.scatter(y_test, y_test_pred1)
plt.show()
